# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
a1p10 = pd.read_csv("p0_testing/alpha_1/a1p10_rcac_pos_states_0.csv")
a1p1 = pd.read_csv("p0_testing/alpha_1/a1p1_rcac_pos_states_0.csv")
a1p0_1 = pd.read_csv("p0_testing/alpha_1/a1p0_1_rcac_pos_states_0.csv")
a1p0_01 = pd.read_csv("p0_testing/alpha_1/a1p0_01_rcac_pos_states_0.csv")
a1p0_001 = pd.read_csv("p0_testing/alpha_1/a1p0_001_rcac_pos_states_0.csv")
a1p0_0001 = pd.read_csv("p0_testing/alpha_1/a1p0_0001_rcac_pos_states_0.csv")
a1p0_00001 = pd.read_csv("p0_testing/alpha_1/a1p0_00001_rcac_pos_states_0.csv")
a1p0_000001 = pd.read_csv("p0_testing/alpha_1/a1p0_000001_rcac_pos_states_0.csv")
a1p0_0000001 = pd.read_csv("p0_testing/alpha_1/a1p0_0000001_rcac_pos_states_0.csv")
a1p0_00000001 = pd.read_csv("p0_testing/alpha_1/a1p0_00000001_rcac_pos_states_0.csv")

# %%
a08p10 = pd.read_csv("p0_testing/alpha_0_8/a08p10_rcac_pos_states_0.csv")
a08p1 = pd.read_csv("p0_testing/alpha_0_8/a08p1_rcac_pos_states_0.csv")
a08p0_1 = pd.read_csv("p0_testing/alpha_0_8/a08p0_1_rcac_pos_states_0.csv")
a08p0_01 = pd.read_csv("p0_testing/alpha_0_8/a08p0_01_rcac_pos_states_0.csv")
a08p0_001 = pd.read_csv("p0_testing/alpha_0_8/a08p0_001_rcac_pos_states_0.csv")
a08p0_0001 = pd.read_csv("p0_testing/alpha_0_8/a08p0_0001_rcac_pos_states_0.csv")
a08p0_00001 = pd.read_csv("p0_testing/alpha_0_8/a08p0_00001_rcac_pos_states_0.csv")
a08p0_000001 = pd.read_csv("p0_testing/alpha_0_8/a08p0_000001_rcac_pos_states_0.csv")
a08p0_0000001 = pd.read_csv("p0_testing/alpha_0_8/a08p0_0000001_rcac_pos_states_0.csv")
a08p0_00000001 = pd.read_csv("p0_testing/alpha_0_8/a08p0_00000001_rcac_pos_states_0.csv")

# %%
a06p10 = pd.read_csv("p0_testing/alpha_0_6/a06p10_rcac_pos_states_0.csv")
a06p1 = pd.read_csv("p0_testing/alpha_0_6/a06p1_rcac_pos_states_0.csv")
a06p0_1 = pd.read_csv("p0_testing/alpha_0_6/a06p0_1_rcac_pos_states_0.csv")
a06p0_01 = pd.read_csv("p0_testing/alpha_0_6/a06p0_01_rcac_pos_states_0.csv")
a06p0_001 = pd.read_csv("p0_testing/alpha_0_6/a06p0_001_rcac_pos_states_0.csv")
a06p0_0001 = pd.read_csv("p0_testing/alpha_0_6/a06p0_0001_rcac_pos_states_0.csv")
a06p0_00001 = pd.read_csv("p0_testing/alpha_0_6/a06p0_00001_rcac_pos_states_0.csv")
a06p0_000001 = pd.read_csv("p0_testing/alpha_0_6/a06p0_000001_rcac_pos_states_0.csv")
a06p0_0000001 = pd.read_csv("p0_testing/alpha_0_6/a06p0_0000001_rcac_pos_states_0.csv")
a06p0_00000001 = pd.read_csv("p0_testing/alpha_0_6/a06p0_00000001_rcac_pos_states_0.csv")

# %%
a04p10 = pd.read_csv("p0_testing/alpha_0_4/a04p10_rcac_pos_states_0.csv")
a04p1 = pd.read_csv("p0_testing/alpha_0_4/a04p1_rcac_pos_states_0.csv")
a04p0_1 = pd.read_csv("p0_testing/alpha_0_4/a04p0_1_rcac_pos_states_0.csv")
a04p0_01 = pd.read_csv("p0_testing/alpha_0_4/a04p0_01_rcac_pos_states_0.csv")
a04p0_001 = pd.read_csv("p0_testing/alpha_0_4/a04p0_001_rcac_pos_states_0.csv")
a04p0_0001 = pd.read_csv("p0_testing/alpha_0_4/a04p0_0001_rcac_pos_states_0.csv")
a04p0_00001 = pd.read_csv("p0_testing/alpha_0_4/a04p0_00001_rcac_pos_states_0.csv")
a04p0_000001 = pd.read_csv("p0_testing/alpha_0_4/a04p0_000001_rcac_pos_states_0.csv")
a04p0_0000001 = pd.read_csv("p0_testing/alpha_0_4/a04p0_0000001_rcac_pos_states_0.csv")
a04p0_00000001 = pd.read_csv("p0_testing/alpha_0_4/a04p0_00000001_rcac_pos_states_0.csv")

# %%
a02p10 = pd.read_csv("p0_testing/alpha_0_2/a02p10_rcac_pos_states_0.csv")
a02p1 = pd.read_csv("p0_testing/alpha_0_2/a02p1_rcac_pos_states_0.csv")
a02p0_1 = pd.read_csv("p0_testing/alpha_0_2/a02p0_1_rcac_pos_states_0.csv")
a02p0_01 = pd.read_csv("p0_testing/alpha_0_2/a02p0_01_rcac_pos_states_0.csv")
a02p0_001 = pd.read_csv("p0_testing/alpha_0_2/a02p0_001_rcac_pos_states_0.csv")
a02p0_0001 = pd.read_csv("p0_testing/alpha_0_2/a02p0_0001_rcac_pos_states_0.csv")
a02p0_00001 = pd.read_csv("p0_testing/alpha_0_2/a02p0_00001_rcac_pos_states_0.csv")
a02p0_000001 = pd.read_csv("p0_testing/alpha_0_2/a02p0_000001_rcac_pos_states_0.csv")
a02p0_0000001 = pd.read_csv("p0_testing/alpha_0_2/a02p0_0000001_rcac_pos_states_0.csv")
a02p0_00000001 = pd.read_csv("p0_testing/alpha_0_2/a02p0_00000001_rcac_pos_states_0.csv")

# %%
pd.read_csv("p0_testing/alpha_1/a1p10_rcac_pos_states_0.csv")
# Out:
#      timestamp      u_pos[0]      u_pos[1]      u_pos[2]      z_pos[0]  \
# 0     21232000  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1     21328000  2.449353e-09 -5.162543e-09 -2.022792e-09  0.000000e+00
# 2     21428000  6.529490e-07 -5.128136e-08 -4.894665e-06  2.723754e-07
# 3     21524000  6.598190e-06 -1.470396e-07 -3.828900e-04  4.141604e-06
# 4     21620000  2.750410e-05 -2.776344e-07 -7.524776e-03  2.024217e-05
# ..         ...           ...           ...           ...           ...
# 838  105144000 -1.565121e-01 -4.193661e-02  9.552847e+00 -1.557386e-01
# 839  105264000 -1.616987e-01 -4.942014e-02  1.030708e+01 -1.609985e-01
# 840  105360000 -1.660548e-01 -5.463368e-02  1.093121e+01 -1.649231e-01
# 841  105456000 -1.710921e-01 -5.949011e-02  1.157365e+01 -1.696187e-01
# 842  105480000 -1.721874e-01 -6.067252e-02  1.173583e+01 -1.710921e-01
#
#          z_pos[1]   z_pos[2]  theta_pos[0]  theta_pos[1]  theta_pos[2]
# ...

# %%
#mod_time = (p0_1_a_1.timestamp-p0_1_a_1.timestamp[0])/(10^8)
p0 = [10, 1, 0.1, 0.01, 0.001, 0.0001, 0.00001, 0.000001, 0.0000001, 0.00000001]
znorm_a1 = []
znorm_a1.append(np.linalg.norm(a1p10['z_pos[0]']) + np.linalg.norm(a1p10['z_pos[1]']) + np.linalg.norm(a1p10['z_pos[2]']))
znorm_a1.append(np.linalg.norm(a1p1['z_pos[0]']) + np.linalg.norm(a1p1['z_pos[1]']) + np.linalg.norm(a1p1['z_pos[2]']))
znorm_a1.append(np.linalg.norm(a1p0_1['z_pos[0]']) + np.linalg.norm(a1p0_1['z_pos[1]']) + np.linalg.norm(a1p0_1['z_pos[2]']))
znorm_a1.append(np.linalg.norm(a1p0_01['z_pos[0]']) + np.linalg.norm(a1p0_01['z_pos[1]']) + np.linalg.norm(a1p0_01['z_pos[2]']))
znorm_a1.append(np.linalg.norm(a1p0_001['z_pos[0]']) + np.linalg.norm(a1p0_001['z_pos[1]']) + np.linalg.norm(a1p0_001['z_pos[2]']))
znorm_a1.append(np.linalg.norm(a1p0_0001['z_pos[0]']) + np.linalg.norm(a1p0_0001['z_pos[1]']) + np.linalg.norm(a1p0_0001['z_pos[2]']))
znorm_a1.append(np.linalg.norm(a1p0_00001['z_pos[0]']) + np.linalg.norm(a1p0_00001['z_pos[1]']) + np.linalg.norm(a1p0_00001['z_pos[2]']))
znorm_a1.append(np.linalg.norm(a1p0_000001['z_pos[0]']) + np.linalg.norm(a1p0_000001['z_pos[1]']) + np.linalg.norm(a1p0_000001['z_pos[2]']))
znorm_a1.append(np.linalg.norm(a1p0_0000001['z_pos[0]']) + np.linalg.norm(a1p0_0000001['z_pos[1]']) + np.linalg.norm(a1p0_0000001['z_pos[2]']))
znorm_a1.append(np.linalg.norm(a1p0_00000001['z_pos[0]']) + np.linalg.norm(a1p0_00000001['z_pos[1]']) + np.linalg.norm(a1p0_00000001['z_pos[2]']))

# %%
znorm_a8 = []
znorm_a8.append(np.linalg.norm(a08p10['z_pos[0]']) + np.linalg.norm(a08p10['z_pos[1]']) + np.linalg.norm(a08p10['z_pos[2]']))
znorm_a8.append(np.linalg.norm(a08p1['z_pos[0]']) + np.linalg.norm(a08p1['z_pos[1]']) + np.linalg.norm(a08p1['z_pos[2]']))
znorm_a8.append(np.linalg.norm(a08p0_1['z_pos[0]']) + np.linalg.norm(a08p0_1['z_pos[1]']) + np.linalg.norm(a08p0_1['z_pos[2]']))
znorm_a8.append(np.linalg.norm(a08p0_01['z_pos[0]']) + np.linalg.norm(a08p0_01['z_pos[1]']) + np.linalg.norm(a08p0_01['z_pos[2]']))
znorm_a8.append(np.linalg.norm(a08p0_001['z_pos[0]']) + np.linalg.norm(a08p0_001['z_pos[1]']) + np.linalg.norm(a08p0_001['z_pos[2]']))
znorm_a8.append(np.linalg.norm(a08p0_0001['z_pos[0]']) + np.linalg.norm(a08p0_0001['z_pos[1]']) + np.linalg.norm(a08p0_0001['z_pos[2]']))
znorm_a8.append(np.linalg.norm(a08p0_00001['z_pos[0]']) + np.linalg.norm(a08p0_00001['z_pos[1]']) + np.linalg.norm(a08p0_00001['z_pos[2]']))
znorm_a8.append(np.linalg.norm(a08p0_000001['z_pos[0]']) + np.linalg.norm(a08p0_000001['z_pos[1]']) + np.linalg.norm(a08p0_000001['z_pos[2]']))
znorm_a8.append(np.linalg.norm(a08p0_0000001['z_pos[0]']) + np.linalg.norm(a08p0_0000001['z_pos[1]']) + np.linalg.norm(a08p0_0000001['z_pos[2]']))
znorm_a8.append(np.linalg.norm(a08p0_00000001['z_pos[0]']) + np.linalg.norm(a08p0_00000001['z_pos[1]']) + np.linalg.norm(a08p0_00000001['z_pos[2]']))

# %%
znorm_a6 = []
znorm_a6.append(np.linalg.norm(a06p10['z_pos[0]']) + np.linalg.norm(a06p10['z_pos[1]']) + np.linalg.norm(a06p10['z_pos[2]']))
znorm_a6.append(np.linalg.norm(a06p1['z_pos[0]']) + np.linalg.norm(a06p1['z_pos[1]']) + np.linalg.norm(a06p1['z_pos[2]']))
znorm_a6.append(np.linalg.norm(a06p0_1['z_pos[0]']) + np.linalg.norm(a06p0_1['z_pos[1]']) + np.linalg.norm(a06p0_1['z_pos[2]']))
znorm_a6.append(np.linalg.norm(a06p0_01['z_pos[0]']) + np.linalg.norm(a06p0_01['z_pos[1]']) + np.linalg.norm(a06p0_01['z_pos[2]']))
znorm_a6.append(np.linalg.norm(a06p0_001['z_pos[0]']) + np.linalg.norm(a06p0_001['z_pos[1]']) + np.linalg.norm(a06p0_001['z_pos[2]']))
znorm_a6.append(np.linalg.norm(a06p0_0001['z_pos[0]']) + np.linalg.norm(a06p0_0001['z_pos[1]']) + np.linalg.norm(a06p0_0001['z_pos[2]']))
znorm_a6.append(np.linalg.norm(a06p0_00001['z_pos[0]']) + np.linalg.norm(a06p0_00001['z_pos[1]']) + np.linalg.norm(a06p0_00001['z_pos[2]']))
znorm_a6.append(np.linalg.norm(a06p0_000001['z_pos[0]']) + np.linalg.norm(a06p0_000001['z_pos[1]']) + np.linalg.norm(a06p0_000001['z_pos[2]']))
znorm_a6.append(np.linalg.norm(a06p0_0000001['z_pos[0]']) + np.linalg.norm(a06p0_0000001['z_pos[1]']) + np.linalg.norm(a06p0_0000001['z_pos[2]']))
znorm_a6.append(np.linalg.norm(a06p0_00000001['z_pos[0]']) + np.linalg.norm(a06p0_00000001['z_pos[1]']) + np.linalg.norm(a06p0_00000001['z_pos[2]']))

# %%
znorm_a4 = []
znorm_a4.append(np.linalg.norm(a04p10['z_pos[0]']) + np.linalg.norm(a04p10['z_pos[1]']) + np.linalg.norm(a04p10['z_pos[2]']))
znorm_a4.append(np.linalg.norm(a04p1['z_pos[0]']) + np.linalg.norm(a04p1['z_pos[1]']) + np.linalg.norm(a04p1['z_pos[2]']))
znorm_a4.append(np.linalg.norm(a04p0_1['z_pos[0]']) + np.linalg.norm(a04p0_1['z_pos[1]']) + np.linalg.norm(a04p0_1['z_pos[2]']))
znorm_a4.append(np.linalg.norm(a04p0_01['z_pos[0]']) + np.linalg.norm(a04p0_01['z_pos[1]']) + np.linalg.norm(a04p0_01['z_pos[2]']))
znorm_a4.append(np.linalg.norm(a04p0_001['z_pos[0]']) + np.linalg.norm(a04p0_001['z_pos[1]']) + np.linalg.norm(a04p0_001['z_pos[2]']))
znorm_a4.append(np.linalg.norm(a04p0_0001['z_pos[0]']) + np.linalg.norm(a04p0_0001['z_pos[1]']) + np.linalg.norm(a04p0_0001['z_pos[2]']))
znorm_a4.append(np.linalg.norm(a04p0_00001['z_pos[0]']) + np.linalg.norm(a04p0_00001['z_pos[1]']) + np.linalg.norm(a04p0_00001['z_pos[2]']))
znorm_a4.append(np.linalg.norm(a04p0_000001['z_pos[0]']) + np.linalg.norm(a04p0_000001['z_pos[1]']) + np.linalg.norm(a04p0_000001['z_pos[2]']))
znorm_a4.append(np.linalg.norm(a04p0_0000001['z_pos[0]']) + np.linalg.norm(a04p0_0000001['z_pos[1]']) + np.linalg.norm(a04p0_0000001['z_pos[2]']))
znorm_a4.append(np.linalg.norm(a04p0_00000001['z_pos[0]']) + np.linalg.norm(a04p0_00000001['z_pos[1]']) + np.linalg.norm(a04p0_00000001['z_pos[2]']))

# %%
znorm_a2 = []
znorm_a2.append(np.linalg.norm(a02p10['z_pos[0]']) + np.linalg.norm(a02p10['z_pos[1]']) + np.linalg.norm(a02p10['z_pos[2]']))
znorm_a2.append(np.linalg.norm(a02p1['z_pos[0]']) + np.linalg.norm(a02p1['z_pos[1]']) + np.linalg.norm(a02p1['z_pos[2]']))
znorm_a2.append(np.linalg.norm(a02p0_1['z_pos[0]']) + np.linalg.norm(a02p0_1['z_pos[1]']) + np.linalg.norm(a02p0_1['z_pos[2]']))
znorm_a2.append(np.linalg.norm(a02p0_01['z_pos[0]']) + np.linalg.norm(a02p0_01['z_pos[1]']) + np.linalg.norm(a02p0_01['z_pos[2]']))
znorm_a2.append(np.linalg.norm(a02p0_001['z_pos[0]']) + np.linalg.norm(a02p0_001['z_pos[1]']) + np.linalg.norm(a02p0_001['z_pos[2]']))
znorm_a2.append(np.linalg.norm(a02p0_0001['z_pos[0]']) + np.linalg.norm(a02p0_0001['z_pos[1]']) + np.linalg.norm(a02p0_0001['z_pos[2]']))
znorm_a2.append(np.linalg.norm(a02p0_00001['z_pos[0]']) + np.linalg.norm(a02p0_00001['z_pos[1]']) + np.linalg.norm(a02p0_00001['z_pos[2]']))
znorm_a2.append(np.linalg.norm(a02p0_000001['z_pos[0]']) + np.linalg.norm(a02p0_000001['z_pos[1]']) + np.linalg.norm(a02p0_000001['z_pos[2]']))
znorm_a2.append(np.linalg.norm(a02p0_0000001['z_pos[0]']) + np.linalg.norm(a02p0_0000001['z_pos[1]']) + np.linalg.norm(a02p0_0000001['z_pos[2]']))
znorm_a2.append(np.linalg.norm(a02p0_00000001['z_pos[0]']) + np.linalg.norm(a02p0_00000001['z_pos[1]']) + np.linalg.norm(a02p0_00000001['z_pos[2]']))

# %%
plt.figure(figsize=(10, 8), dpi=80)
plt.plot(p0, znorm_a1, label = 'alpha 1')
plt.plot(p0, znorm_a8, label = 'alpha 0.8')
plt.plot(p0, znorm_a6, label = 'alpha 0.6')
plt.plot(p0, znorm_a4, label = 'alpha 0.4')
plt.plot(p0, znorm_a2, label = 'alpha 0.2')
plt.legend()
plt.xlabel('P0')
plt.ylabel('Norm of Z')
plt.grid()
plt.xscale('log')
